# %%
import pandas as pd
import random_address
import numpy as np

# %%
name_male = pd.read_csv("D:\jupyter_notebook\SIH\Indian-Male-Names.csv")

# %%
name_male.head()
# Out:
#               name gender    race
# 0          barjraj      m  indian
# 1     ramdin verma      m  indian
# 2  sharat chandran      m  indian
# 3  birender mandal      m  indian
# 4             amit      m  indian

# %%
name_female =  pd.read_csv("D:\jupyter_notebook\SIH\Indian-Female-Names.csv")

# %%
name_female
# Out:
#                             name gender    race
# 0                        shivani      f  indian
# 1                           isha      f  indian
# 2                smt shyani devi      f  indian
# 3                          divya      f  indian
# 4                          mansi      f  indian
# ...                          ...    ...     ...
# 15377                 saroj devi      f  indian
# 15378              naina @ geeta      f  indian
# 15379  manju d/0 baboo lal jatav      f  indian
# 15380                    shivani      f  indian
# 15381                      nayna      f  indian
#
# [15382 rows x 3 columns]

# %%
nm = name_male[:300]

# %%
nf = name_female[:300]

# %%
name = pd.concat([nm,nf])

# %%
type(name)
# Out:
# pandas.core.frame.DataFrame

# %%
type(nf)
# Out:
# pandas.core.frame.DataFrame

# %%
name = np.array(name)

# %%
name = pd.DataFrame(name,columns=["name","gender","race"])

# %%
type(name)
# Out:
# pandas.core.frame.DataFrame

# %%
name = name.sample(frac = 1)

# %%
name.head()
# Out:
#                 name gender    race
# 544      asha kumari      f  indian
# 127            nitin      m  indian
# 583           tripti      f  indian
# 155         som dutt      m  indian
# 121  bhagwati prasad      m  indian

# %%
add = random_address.real_random_address_by_state("CA")

# %%
add
# Out:
# {'address1': '2086 Hillside Drive',
#  'address2': '',
#  'city': 'San Leandro',
#  'state': 'CA',
#  'postalCode': '94577',
#  'coordinates': {'lat': 37.7238372, 'lng': -122.1334006}}

# %%
#add 
#addhar no
#dob
 #your #name, address?, #gender, #date of birth?,#age?, ten finger prints?, facial photograph?, #mobile number (optional)? and #email ID (optional)?,#addhar_no?.

# %%
import random

# %%
phno = []

# %%
for i in range(600):
    phno.append(random.randint(1000000000,9999999999))

# %%
phone_no = np.array(phno)

# %%
phone_no = pd.DataFrame(phone_no,columns=["phone_name"])

# %%
dob = []

# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
from random import choices
test_date1, test_date2 = date(1922, 1,1 ), date(2022, 1, 1)
K = 600
res_dates = [test_date1]
while test_date1 != test_date2:
    test_date1 += timedelta(days=1)
    res_dates.append(test_date1)
res = choices(res_dates, k=K)
dob.append(res)

# %%
phone_no.head()
# Out:
#    phone_name
# 0  7041777811
# 1  7649264094
# 2  3391682466
# 3  8305024990
# 4  6372700974

# %%
from datetime import datetime

# %%
dob_year = []
dob_month = []
dob_day = []
dob_yr = []

# %%
for i in range(600):

    year = dob[0][i].strftime("%Y")
    month = dob[0][i].strftime("%m")
    day = dob[0][i].strftime("%d")
    dob_yr.append(year)
    dob_month.append(month)
    dob_day.append(day)

# %%
dob_year = np.array(dob_yr)
dob_month = np.array(dob_month)
dob_day = np.array(dob_day)

# %%
dob_year = pd.DataFrame(dob_year,columns=["dob_year"])
dob_month = pd.DataFrame(dob_month,columns=["dob_year"])
dob_day = pd.DataFrame(dob_day,columns=["dob_year"])

# %%
dob_year.head()
# Out:
#   dob_year
# 0     1944
# 1     1985
# 2     1946
# 3     1993
# 4     1955

# %%
age =[]
for i in dob_yr:
    age.append(int((date.today().year-int(i))))

# %%
type(age[10])
# Out:
# int

# %%
age = np.array(age)
age = pd.DataFrame(age,columns=["age"])

# %%
age.head()
# Out:
#    age
# 0   78
# 1   37
# 2   76
# 3   29
# 4   67

# %%
addhar_no = []
for i in range(600):
    addhar_no.append(random.randint(100000000000,999999999999))
addhar_no = np.array(addhar_no)
addhar_no = pd.DataFrame(addhar_no,columns=["addhar_no"])

# %%
addhar_no.head()
# Out:
#       addhar_no
# 0  971661941956
# 1  556730133501
# 2  525505683683
# 3  235681252902
# 4  925621932215

# %%
n = np.array(name["name"])

# %%
type(n[1])
# Out:
# str

# %%
index = []
counter = 0
for i in n:
    k = i
    for j in k:
        if(ord(j) >=65 and ord(j)<=122):
            index.append(counter)
    counter +=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-328-0bce14068638> in <module>
#       3 for i in n:
#       4     k = i
# ----> 5     for j in k:
#       6         if(ord(j) >=65 and ord(j)<=122):
#       7             index.append(counter)
#
# TypeError: 'float' object is not iterable

# %%
name["name"][3]
# Out:
# 'birender mandal'

# %%
k = name["name"][3]
counter = 0

for j in n:
        for i in j:
            print(i)
        counter += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-324-4a6a48209260> in <module>
#       3
#       4 for j in n:
# ----> 5         for i in j:
#       6             if (i.isalpha() or i == ' '):
#       7                 index.append(counter)
#
# TypeError: 'float' object is not iterable

# %%
ord("a")
# Out:
# 97

# %%
age
name
phone_no
dob_year 
dob_month 
dob_day 
addhar_no

# %%
name.to_csv("name_600.csv",index= False)

# %%
name = pd.read_csv("D:\jupyter_notebook\SIH\name_600.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-333-b4482111d997> in <module>
# ----> 1 name = pd.read_csv("D:\jupyter_notebook\SIH\name_600.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# OSError: [Errno 22] Invalid argument: 'D:\\jupyter_notebook\\SIH\name_600.csv'

# %%
name_new = pd.read_csv("name_600.csv")

# %%
name_new.head()
# Out:
#               name gender    race
# 0      asha kumari      f  indian
# 1            nitin      m  indian
# 2           tripti      f  indian
# 3         som dutt      m  indian
# 4  bhagwati prasad      m  indian

# %%
email = pd.read_csv("email.csv")

# %%
email.head()
# Out:
#        ashakumari@gmail.com
# 0           nitin@gmail.com
# 1          tripti@gmail.com
# 2         somdutt@gmail.com
# 3  bhagwatiprasad@gmail.com
# 4         yognder@gmail.com

# %%
age
name_new
phone_no
dob_year 
dob_month 
dob_day 
addhar_no
email
# Out:
#          ashakumari@gmail.com
# 0             nitin@gmail.com
# 1            tripti@gmail.com
# 2           somdutt@gmail.com
# 3    bhagwatiprasad@gmail.com
# 4           yognder@gmail.com
# ..                        ...
# 594           vikas@gmail.com
# 595           midda@gmail.com
# 596            tina@gmail.com
# 597           vipin@gmail.com
# 598            azaz@gmail.com
#
# [599 rows x 1 columns]

# %%
import pandas as pd

# %%
d1 = pd.read_csv("data.csv")
d1.head()
# Out:
#               name gender    race  age    phone_no  dob_year  dob_month  \
# 0            nitin      m  indian   39  8870420417      1983          3
# 1           tripti      m  indian   82  6685222304      1940         11
# 2          somdutt      m  indian   22  1769586754      2000          1
# 3  bhagwati prasad      f  indian   96  9150944354      1926          7
# 4          yognder      f  indian    9  8383788450      2013          4
#
#    dob_day     addhar_no                     email  ...  \
# 0        1  5.470000e+11           nitin@gmail.com  ...
# 1       24  5.930000e+11          tripti@gmail.com  ...
# 2        2  6.170000e+11         somdutt@gmail.com  ...
# 3       19  2.550000e+11  bhagwatiprasad@gmail.com  ...
# 4       24  8.950000e+11         yognder@gmail.com  ...
#
#                    img_rgt_thumb                  img_rgt_index  \
# 0  100__M_Right_thumb_finger.BMP  100__M_Right_index_finger.BMP
# 1  101__M_Right_thumb_finger.BMP  101__M_Right_index_finger.BMP
# 2  102__M_Right_thumb_finger.BMP  102__M_Right_index_finger.BMP
# 3  103__F_Right_thumb_finger.BMP  103__F_Right_index_finger.BMP
# 4  104__M_Right_thumb_finger.BMP  104__M_Right_index_finger.BMP
#
#                    img_rgt_middle                  img_rgt_ring  \
# 0  100__M_Right_middle_finger.BMP  100__M_Right_ring_finger.BMP
# 1  101__M_Right_middle_finger.BMP  101__M_Right_ring_finger.BMP
# 2  102__M_Right_middle_finger.BMP  102__M_Right_ring_finger.BMP
# 3  103__F_Right_middle_finger.BMP  103__F_Right_ring_finger.BMP
# 4  104__M_Right_middle_finger.BMP  104__M_Right_ring_finger.BMP
#
#                    img_rgt_little                img_left_thumb  \
# 0  100__M_Right_little_finger.BMP  100__M_Left_thumb_finger.BMP
# 1  101__M_Right_little_finger.BMP  101__M_Left_thumb_finger.BMP
# 2  102__M_Right_little_finger.BMP  102__M_Left_thumb_finger.BMP
# 3  103__F_Right_little_finger.BMP  103__F_Left_thumb_finger.BMP
# 4  104__M_Right_little_finger.BMP  104__M_Left_thumb_finger.BMP
#
#                  img_left_index                img_left_middle  \
# 0  100__M_Left_index_finger.BMP  100__M_Left_middle_finger.BMP
# 1  101__M_Left_index_finger.BMP  101__M_Left_middle_finger.BMP
# 2  102__M_Left_index_finger.BMP  102__M_Left_middle_finger.BMP
# 3  103__F_Left_index_finger.BMP  103__F_Left_middle_finger.BMP
# 4  104__M_Left_index_finger.BMP  104__M_Left_middle_finger.BMP
#
#                  img_left_ring                img_left_little
# 0  100__M_Left_ring_finger.BMP  100__M_Left_little_finger.BMP
# 1  101__M_Left_ring_finger.BMP  101__M_Left_little_finger.BMP
# 2  102__M_Left_ring_finger.BMP  102__M_Left_little_finger.BMP
# 3  103__F_Left_ring_finger.BMP  103__F_Left_little_finger.BMP
# 4  104__M_Left_ring_finger.BMP  104__M_Left_little_finger.BMP
#
# [5 rows x 22 columns]

# %%
d2 = d1.copy()
d2.head()
# Out:
#               name gender    race  age    phone_no  dob_year  dob_month  \
# 0            nitin      m  indian   39  8870420417      1983          3
# 1           tripti      m  indian   82  6685222304      1940         11
# 2          somdutt      m  indian   22  1769586754      2000          1
# 3  bhagwati prasad      f  indian   96  9150944354      1926          7
# 4          yognder      f  indian    9  8383788450      2013          4
#
#    dob_day     addhar_no                     email  ...  \
# 0        1  5.470000e+11           nitin@gmail.com  ...
# 1       24  5.930000e+11          tripti@gmail.com  ...
# 2        2  6.170000e+11         somdutt@gmail.com  ...
# 3       19  2.550000e+11  bhagwatiprasad@gmail.com  ...
# 4       24  8.950000e+11         yognder@gmail.com  ...
#
#                    img_rgt_thumb                  img_rgt_index  \
# 0  100__M_Right_thumb_finger.BMP  100__M_Right_index_finger.BMP
# 1  101__M_Right_thumb_finger.BMP  101__M_Right_index_finger.BMP
# 2  102__M_Right_thumb_finger.BMP  102__M_Right_index_finger.BMP
# 3  103__F_Right_thumb_finger.BMP  103__F_Right_index_finger.BMP
# 4  104__M_Right_thumb_finger.BMP  104__M_Right_index_finger.BMP
#
#                    img_rgt_middle                  img_rgt_ring  \
# 0  100__M_Right_middle_finger.BMP  100__M_Right_ring_finger.BMP
# 1  101__M_Right_middle_finger.BMP  101__M_Right_ring_finger.BMP
# 2  102__M_Right_middle_finger.BMP  102__M_Right_ring_finger.BMP
# 3  103__F_Right_middle_finger.BMP  103__F_Right_ring_finger.BMP
# 4  104__M_Right_middle_finger.BMP  104__M_Right_ring_finger.BMP
#
#                    img_rgt_little                img_left_thumb  \
# 0  100__M_Right_little_finger.BMP  100__M_Left_thumb_finger.BMP
# 1  101__M_Right_little_finger.BMP  101__M_Left_thumb_finger.BMP
# 2  102__M_Right_little_finger.BMP  102__M_Left_thumb_finger.BMP
# 3  103__F_Right_little_finger.BMP  103__F_Left_thumb_finger.BMP
# 4  104__M_Right_little_finger.BMP  104__M_Left_thumb_finger.BMP
#
#                  img_left_index                img_left_middle  \
# 0  100__M_Left_index_finger.BMP  100__M_Left_middle_finger.BMP
# 1  101__M_Left_index_finger.BMP  101__M_Left_middle_finger.BMP
# 2  102__M_Left_index_finger.BMP  102__M_Left_middle_finger.BMP
# 3  103__F_Left_index_finger.BMP  103__F_Left_middle_finger.BMP
# 4  104__M_Left_index_finger.BMP  104__M_Left_middle_finger.BMP
#
#                  img_left_ring                img_left_little
# 0  100__M_Left_ring_finger.BMP  100__M_Left_little_finger.BMP
# 1  101__M_Left_ring_finger.BMP  101__M_Left_little_finger.BMP
# 2  102__M_Left_ring_finger.BMP  102__M_Left_little_finger.BMP
# 3  103__F_Left_ring_finger.BMP  103__F_Left_little_finger.BMP
# 4  104__M_Left_ring_finger.BMP  104__M_Left_little_finger.BMP
#
# [5 rows x 22 columns]

# %%
d2['gender'].replace('m','Male',inplace=True)
d2['gender'].replace('f','Female',inplace=True)

# %%
d2['race'].replace('indian','Indian',inplace=True)

# %%
d2.head()
# Out:
#               name  gender    race  age    phone_no  dob_year  dob_month  \
# 0            nitin    Male  Indian   39  8870420417      1983          3
# 1           tripti    Male  Indian   82  6685222304      1940         11
# 2          somdutt    Male  Indian   22  1769586754      2000          1
# 3  bhagwati prasad  Female  Indian   96  9150944354      1926          7
# 4          yognder  Female  Indian    9  8383788450      2013          4
#
#    dob_day     addhar_no                     email  ...  \
# 0        1  5.470000e+11           nitin@gmail.com  ...
# 1       24  5.930000e+11          tripti@gmail.com  ...
# 2        2  6.170000e+11         somdutt@gmail.com  ...
# 3       19  2.550000e+11  bhagwatiprasad@gmail.com  ...
# 4       24  8.950000e+11         yognder@gmail.com  ...
#
#                    img_rgt_thumb                  img_rgt_index  \
# 0  100__M_Right_thumb_finger.BMP  100__M_Right_index_finger.BMP
# 1  101__M_Right_thumb_finger.BMP  101__M_Right_index_finger.BMP
# 2  102__M_Right_thumb_finger.BMP  102__M_Right_index_finger.BMP
# 3  103__F_Right_thumb_finger.BMP  103__F_Right_index_finger.BMP
# 4  104__M_Right_thumb_finger.BMP  104__M_Right_index_finger.BMP
#
#                    img_rgt_middle                  img_rgt_ring  \
# 0  100__M_Right_middle_finger.BMP  100__M_Right_ring_finger.BMP
# 1  101__M_Right_middle_finger.BMP  101__M_Right_ring_finger.BMP
# 2  102__M_Right_middle_finger.BMP  102__M_Right_ring_finger.BMP
# 3  103__F_Right_middle_finger.BMP  103__F_Right_ring_finger.BMP
# 4  104__M_Right_middle_finger.BMP  104__M_Right_ring_finger.BMP
#
#                    img_rgt_little                img_left_thumb  \
# 0  100__M_Right_little_finger.BMP  100__M_Left_thumb_finger.BMP
# 1  101__M_Right_little_finger.BMP  101__M_Left_thumb_finger.BMP
# 2  102__M_Right_little_finger.BMP  102__M_Left_thumb_finger.BMP
# 3  103__F_Right_little_finger.BMP  103__F_Left_thumb_finger.BMP
# 4  104__M_Right_little_finger.BMP  104__M_Left_thumb_finger.BMP
#
#                  img_left_index                img_left_middle  \
# 0  100__M_Left_index_finger.BMP  100__M_Left_middle_finger.BMP
# 1  101__M_Left_index_finger.BMP  101__M_Left_middle_finger.BMP
# 2  102__M_Left_index_finger.BMP  102__M_Left_middle_finger.BMP
# 3  103__F_Left_index_finger.BMP  103__F_Left_middle_finger.BMP
# 4  104__M_Left_index_finger.BMP  104__M_Left_middle_finger.BMP
#
#                  img_left_ring                img_left_little
# 0  100__M_Left_ring_finger.BMP  100__M_Left_little_finger.BMP
# 1  101__M_Left_ring_finger.BMP  101__M_Left_little_finger.BMP
# 2  102__M_Left_ring_finger.BMP  102__M_Left_little_finger.BMP
# 3  103__F_Left_ring_finger.BMP  103__F_Left_little_finger.BMP
# 4  104__M_Left_ring_finger.BMP  104__M_Left_little_finger.BMP
#
# [5 rows x 22 columns]

# %%
# d2['Date of Birth'] = d2['dob_day'].astype(str) + '-' + d2['dob_month'].astype(str) + '-' + d2['dob_year'].astype(str)
d2.insert(5,'Date of Birth',d2['dob_day'].astype(str) + '-' + d2['dob_month'].astype(str) + '-' + d2['dob_year'].astype(str))

# %%
d2.head()
# Out:
#               name  gender    race  age    phone_no Date of Birth  dob_year  \
# 0            nitin    Male  Indian   39  8870420417      1-3-1983      1983
# 1           tripti    Male  Indian   82  6685222304    24-11-1940      1940
# 2          somdutt    Male  Indian   22  1769586754      2-1-2000      2000
# 3  bhagwati prasad  Female  Indian   96  9150944354     19-7-1926      1926
# 4          yognder  Female  Indian    9  8383788450     24-4-2013      2013
#
#    dob_month  dob_day     addhar_no  ...                  img_rgt_thumb  \
# 0          3        1  5.470000e+11  ...  100__M_Right_thumb_finger.BMP
# 1         11       24  5.930000e+11  ...  101__M_Right_thumb_finger.BMP
# 2          1        2  6.170000e+11  ...  102__M_Right_thumb_finger.BMP
# 3          7       19  2.550000e+11  ...  103__F_Right_thumb_finger.BMP
# 4          4       24  8.950000e+11  ...  104__M_Right_thumb_finger.BMP
#
#                    img_rgt_index                  img_rgt_middle  \
# 0  100__M_Right_index_finger.BMP  100__M_Right_middle_finger.BMP
# 1  101__M_Right_index_finger.BMP  101__M_Right_middle_finger.BMP
# 2  102__M_Right_index_finger.BMP  102__M_Right_middle_finger.BMP
# 3  103__F_Right_index_finger.BMP  103__F_Right_middle_finger.BMP
# 4  104__M_Right_index_finger.BMP  104__M_Right_middle_finger.BMP
#
#                    img_rgt_ring                  img_rgt_little  \
# 0  100__M_Right_ring_finger.BMP  100__M_Right_little_finger.BMP
# 1  101__M_Right_ring_finger.BMP  101__M_Right_little_finger.BMP
# 2  102__M_Right_ring_finger.BMP  102__M_Right_little_finger.BMP
# 3  103__F_Right_ring_finger.BMP  103__F_Right_little_finger.BMP
# 4  104__M_Right_ring_finger.BMP  104__M_Right_little_finger.BMP
#
#                  img_left_thumb                img_left_index  \
# 0  100__M_Left_thumb_finger.BMP  100__M_Left_index_finger.BMP
# 1  101__M_Left_thumb_finger.BMP  101__M_Left_index_finger.BMP
# 2  102__M_Left_thumb_finger.BMP  102__M_Left_index_finger.BMP
# 3  103__F_Left_thumb_finger.BMP  103__F_Left_index_finger.BMP
# 4  104__M_Left_thumb_finger.BMP  104__M_Left_index_finger.BMP
#
#                  img_left_middle                img_left_ring  \
# 0  100__M_Left_middle_finger.BMP  100__M_Left_ring_finger.BMP
# 1  101__M_Left_middle_finger.BMP  101__M_Left_ring_finger.BMP
# 2  102__M_Left_middle_finger.BMP  102__M_Left_ring_finger.BMP
# 3  103__F_Left_middle_finger.BMP  103__F_Left_ring_finger.BMP
# 4  104__M_Left_middle_finger.BMP  104__M_Left_ring_finger.BMP
#
#                  img_left_little
# 0  100__M_Left_little_finger.BMP
# 1  101__M_Left_little_finger.BMP
# 2  102__M_Left_little_finger.BMP
# 3  103__F_Left_little_finger.BMP
# 4  104__M_Left_little_finger.BMP
#
# [5 rows x 23 columns]

# %%
d2.drop(['dob_year','dob_month','dob_day'],axis=1,inplace=True)

# %%
d2.head()
# Out:
#               name  gender    race  age    phone_no Date of Birth  \
# 0            nitin    Male  Indian   39  8870420417      1-3-1983
# 1           tripti    Male  Indian   82  6685222304    24-11-1940
# 2          somdutt    Male  Indian   22  1769586754      2-1-2000
# 3  bhagwati prasad  Female  Indian   96  9150944354     19-7-1926
# 4          yognder  Female  Indian    9  8383788450     24-4-2013
#
#       addhar_no                     email  \
# 0  5.470000e+11           nitin@gmail.com
# 1  5.930000e+11          tripti@gmail.com
# 2  6.170000e+11         somdutt@gmail.com
# 3  2.550000e+11  bhagwatiprasad@gmail.com
# 4  8.950000e+11         yognder@gmail.com
#
#                                              address              state  \
# 0     H.No. 688\r\nSrinivas Path\r\nAmaravati-140368             Kerala
# 1            H.No. 05\r\nBal Marg, Ahmednagar-439474             Punjab
# 2         26/342, Zachariah Circle\r\nSolapur-535546  Arunachal Pradesh
# 3  047, Krishnan Zila, Raurkela Industrial Townsh...          Karnataka
# 4                  207\r\nBehl Marg\r\nKollam 644605              Bihar
#
#                    img_rgt_thumb                  img_rgt_index  \
# 0  100__M_Right_thumb_finger.BMP  100__M_Right_index_finger.BMP
# 1  101__M_Right_thumb_finger.BMP  101__M_Right_index_finger.BMP
# 2  102__M_Right_thumb_finger.BMP  102__M_Right_index_finger.BMP
# 3  103__F_Right_thumb_finger.BMP  103__F_Right_index_finger.BMP
# 4  104__M_Right_thumb_finger.BMP  104__M_Right_index_finger.BMP
#
#                    img_rgt_middle                  img_rgt_ring  \
# 0  100__M_Right_middle_finger.BMP  100__M_Right_ring_finger.BMP
# 1  101__M_Right_middle_finger.BMP  101__M_Right_ring_finger.BMP
# 2  102__M_Right_middle_finger.BMP  102__M_Right_ring_finger.BMP
# 3  103__F_Right_middle_finger.BMP  103__F_Right_ring_finger.BMP
# 4  104__M_Right_middle_finger.BMP  104__M_Right_ring_finger.BMP
#
#                    img_rgt_little                img_left_thumb  \
# 0  100__M_Right_little_finger.BMP  100__M_Left_thumb_finger.BMP
# 1  101__M_Right_little_finger.BMP  101__M_Left_thumb_finger.BMP
# 2  102__M_Right_little_finger.BMP  102__M_Left_thumb_finger.BMP
# 3  103__F_Right_little_finger.BMP  103__F_Left_thumb_finger.BMP
# 4  104__M_Right_little_finger.BMP  104__M_Left_thumb_finger.BMP
#
#                  img_left_index                img_left_middle  \
# 0  100__M_Left_index_finger.BMP  100__M_Left_middle_finger.BMP
# 1  101__M_Left_index_finger.BMP  101__M_Left_middle_finger.BMP
# 2  102__M_Left_index_finger.BMP  102__M_Left_middle_finger.BMP
# 3  103__F_Left_index_finger.BMP  103__F_Left_middle_finger.BMP
# 4  104__M_Left_index_finger.BMP  104__M_Left_middle_finger.BMP
#
#                  img_left_ring                img_left_little
# 0  100__M_Left_ring_finger.BMP  100__M_Left_little_finger.BMP
# 1  101__M_Left_ring_finger.BMP  101__M_Left_little_finger.BMP
# 2  102__M_Left_ring_finger.BMP  102__M_Left_little_finger.BMP
# 3  103__F_Left_ring_finger.BMP  103__F_Left_little_finger.BMP
# 4  104__M_Left_ring_finger.BMP  104__M_Left_little_finger.BMP

# %%
d2.to_csv('data2.csv',index=False)

# %%
d2['aadhar_no'] = [int(i) for i in d2['addhar_no']]

# %%
d2.head()
# Out:
#               name  gender    race  age    phone_no Date of Birth  \
# 0            nitin    Male  Indian   39  8870420417      1-3-1983
# 1           tripti    Male  Indian   82  6685222304    24-11-1940
# 2          somdutt    Male  Indian   22  1769586754      2-1-2000
# 3  bhagwati prasad  Female  Indian   96  9150944354     19-7-1926
# 4          yognder  Female  Indian    9  8383788450     24-4-2013
#
#       addhar_no                     email  \
# 0  5.470000e+11           nitin@gmail.com
# 1  5.930000e+11          tripti@gmail.com
# 2  6.170000e+11         somdutt@gmail.com
# 3  2.550000e+11  bhagwatiprasad@gmail.com
# 4  8.950000e+11         yognder@gmail.com
#
#                                              address              state  ...  \
# 0     H.No. 688\r\nSrinivas Path\r\nAmaravati-140368             Kerala  ...
# 1            H.No. 05\r\nBal Marg, Ahmednagar-439474             Punjab  ...
# 2         26/342, Zachariah Circle\r\nSolapur-535546  Arunachal Pradesh  ...
# 3  047, Krishnan Zila, Raurkela Industrial Townsh...          Karnataka  ...
# 4                  207\r\nBehl Marg\r\nKollam 644605              Bihar  ...
#
#                    img_rgt_index                  img_rgt_middle  \
# 0  100__M_Right_index_finger.BMP  100__M_Right_middle_finger.BMP
# 1  101__M_Right_index_finger.BMP  101__M_Right_middle_finger.BMP
# 2  102__M_Right_index_finger.BMP  102__M_Right_middle_finger.BMP
# 3  103__F_Right_index_finger.BMP  103__F_Right_middle_finger.BMP
# 4  104__M_Right_index_finger.BMP  104__M_Right_middle_finger.BMP
#
#                    img_rgt_ring                  img_rgt_little  \
# 0  100__M_Right_ring_finger.BMP  100__M_Right_little_finger.BMP
# 1  101__M_Right_ring_finger.BMP  101__M_Right_little_finger.BMP
# 2  102__M_Right_ring_finger.BMP  102__M_Right_little_finger.BMP
# 3  103__F_Right_ring_finger.BMP  103__F_Right_little_finger.BMP
# 4  104__M_Right_ring_finger.BMP  104__M_Right_little_finger.BMP
#
#                  img_left_thumb                img_left_index  \
# 0  100__M_Left_thumb_finger.BMP  100__M_Left_index_finger.BMP
# 1  101__M_Left_thumb_finger.BMP  101__M_Left_index_finger.BMP
# 2  102__M_Left_thumb_finger.BMP  102__M_Left_index_finger.BMP
# 3  103__F_Left_thumb_finger.BMP  103__F_Left_index_finger.BMP
# 4  104__M_Left_thumb_finger.BMP  104__M_Left_index_finger.BMP
#
#                  img_left_middle                img_left_ring  \
# 0  100__M_Left_middle_finger.BMP  100__M_Left_ring_finger.BMP
# 1  101__M_Left_middle_finger.BMP  101__M_Left_ring_finger.BMP
# 2  102__M_Left_middle_finger.BMP  102__M_Left_ring_finger.BMP
# 3  103__F_Left_middle_finger.BMP  103__F_Left_ring_finger.BMP
# 4  104__M_Left_middle_finger.BMP  104__M_Left_ring_finger.BMP
#
#                  img_left_little     aadhar_no
# 0  100__M_Left_little_finger.BMP  547000000000
# 1  101__M_Left_little_finger.BMP  593000000000
# 2  102__M_Left_little_finger.BMP  617000000000
# 3  103__F_Left_little_finger.BMP  255000000000
# 4  104__M_Left_little_finger.BMP  895000000000
#
# [5 rows x 21 columns]

# %%
d2.drop(['addhar_no'],axis=1,inplace=True)

# %%
d2.insert(6,'Aadhar Number',d2['aadhar_no'])
d2.head()
# Out:
#               name  gender    race  age    phone_no Date of Birth  \
# 0            nitin    Male  Indian   39  8870420417      1-3-1983
# 1           tripti    Male  Indian   82  6685222304    24-11-1940
# 2          somdutt    Male  Indian   22  1769586754      2-1-2000
# 3  bhagwati prasad  Female  Indian   96  9150944354     19-7-1926
# 4          yognder  Female  Indian    9  8383788450     24-4-2013
#
#    Aadhar Number                     email  \
# 0   547000000000           nitin@gmail.com
# 1   593000000000          tripti@gmail.com
# 2   617000000000         somdutt@gmail.com
# 3   255000000000  bhagwatiprasad@gmail.com
# 4   895000000000         yognder@gmail.com
#
#                                              address              state  ...  \
# 0     H.No. 688\r\nSrinivas Path\r\nAmaravati-140368             Kerala  ...
# 1            H.No. 05\r\nBal Marg, Ahmednagar-439474             Punjab  ...
# 2         26/342, Zachariah Circle\r\nSolapur-535546  Arunachal Pradesh  ...
# 3  047, Krishnan Zila, Raurkela Industrial Townsh...          Karnataka  ...
# 4                  207\r\nBehl Marg\r\nKollam 644605              Bihar  ...
#
#                    img_rgt_index                  img_rgt_middle  \
# 0  100__M_Right_index_finger.BMP  100__M_Right_middle_finger.BMP
# 1  101__M_Right_index_finger.BMP  101__M_Right_middle_finger.BMP
# 2  102__M_Right_index_finger.BMP  102__M_Right_middle_finger.BMP
# 3  103__F_Right_index_finger.BMP  103__F_Right_middle_finger.BMP
# 4  104__M_Right_index_finger.BMP  104__M_Right_middle_finger.BMP
#
#                    img_rgt_ring                  img_rgt_little  \
# 0  100__M_Right_ring_finger.BMP  100__M_Right_little_finger.BMP
# 1  101__M_Right_ring_finger.BMP  101__M_Right_little_finger.BMP
# 2  102__M_Right_ring_finger.BMP  102__M_Right_little_finger.BMP
# 3  103__F_Right_ring_finger.BMP  103__F_Right_little_finger.BMP
# 4  104__M_Right_ring_finger.BMP  104__M_Right_little_finger.BMP
#
#                  img_left_thumb                img_left_index  \
# 0  100__M_Left_thumb_finger.BMP  100__M_Left_index_finger.BMP
# 1  101__M_Left_thumb_finger.BMP  101__M_Left_index_finger.BMP
# 2  102__M_Left_thumb_finger.BMP  102__M_Left_index_finger.BMP
# 3  103__F_Left_thumb_finger.BMP  103__F_Left_index_finger.BMP
# 4  104__M_Left_thumb_finger.BMP  104__M_Left_index_finger.BMP
#
#                  img_left_middle                img_left_ring  \
# 0  100__M_Left_middle_finger.BMP  100__M_Left_ring_finger.BMP
# 1  101__M_Left_middle_finger.BMP  101__M_Left_ring_finger.BMP
# 2  102__M_Left_middle_finger.BMP  102__M_Left_ring_finger.BMP
# 3  103__F_Left_middle_finger.BMP  103__F_Left_ring_finger.BMP
# 4  104__M_Left_middle_finger.BMP  104__M_Left_ring_finger.BMP
#
#                  img_left_little     aadhar_no
# 0  100__M_Left_little_finger.BMP  547000000000
# 1  101__M_Left_little_finger.BMP  593000000000
# 2  102__M_Left_little_finger.BMP  617000000000
# 3  103__F_Left_little_finger.BMP  255000000000
# 4  104__M_Left_little_finger.BMP  895000000000
#
# [5 rows x 21 columns]

# %%
d2.drop(['aadhar_no'],axis=1,inplace=True)

# %%
d2.drop(['email','img_rgt_thumb','img_rgt_index','img_rgt_middle','img_rgt_ring',
        'img_rgt_little','img_left_thumb','img_left_index','img_left_middle',
        'img_left_ring','img_left_little'],axis=1,inplace=True)

# %%
d2.to_csv('data2.csv',index=False)

# %%
d2.head()
# Out:
#               name  gender    race  age    phone_no Date of Birth  \
# 0            nitin    Male  Indian   39  8870420417      1-3-1983
# 1           tripti    Male  Indian   82  6685222304    24-11-1940
# 2          somdutt    Male  Indian   22  1769586754      2-1-2000
# 3  bhagwati prasad  Female  Indian   96  9150944354     19-7-1926
# 4          yognder  Female  Indian    9  8383788450     24-4-2013
#
#    Aadhar Number                                            address  \
# 0   547000000000     H.No. 688\r\nSrinivas Path\r\nAmaravati-140368
# 1   593000000000            H.No. 05\r\nBal Marg, Ahmednagar-439474
# 2   617000000000         26/342, Zachariah Circle\r\nSolapur-535546
# 3   255000000000  047, Krishnan Zila, Raurkela Industrial Townsh...
# 4   895000000000                  207\r\nBehl Marg\r\nKollam 644605
#
#                state
# 0             Kerala
# 1             Punjab
# 2  Arunachal Pradesh
# 3          Karnataka
# 4              Bihar

# %%
d2['Aadhar Number'] = [str(i)[0:4]+' '+str(i)[4:8]+' '+str(i)[8:12] for i in d2['Aadhar Number']]

# %%
d2.to_csv('data2.csv',index=False)
